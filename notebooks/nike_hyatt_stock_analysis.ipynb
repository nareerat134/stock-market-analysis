# %% [markdown]
# **Stock Analysis for NIKE & Hyatt**
#
# Authors: Dajia Forbes & Nareerat Khemphed
#
# Date Started: Febuary 23,2024
#
# Course: CSCI 610-Programming for Data Science
#
# Instructor: Rachit Kapoor
#
# Project Overview
#
# This project aims to enhance Python proficiency by retrieving and analyzing NIKE & Hyatt stock data from Yahoo Finance using APIs. Through hands-on experience with pandas, we will develop skills in data manipulation and analysis. The project culminates in visualizing stock price trends, fostering an improved understanding of basic data science operations. By interpreting these trends, participants will refine their analytical abilities and gain insights into the dynamics of the stock market.

# %%
import pandas as pd #retrieves the necessary package requires to conduct the project

# %%
# !pip install yfinance #installs yahoo finace to receive the stock data

# %%
import yfinance as yf #imports the yfinace libaray

# %%
import matplotlib as plt #imports matplotlib so we can create plots for data visualization

# %%
import datetime as dt #imports date time so we can get dates

# %% [markdown]
# # ****NIKE STOCK ANALYSIS****

# %% [markdown]
# # **Data Fetching - Short Term Analysis (20 Days)**

# %%
ticker_symbol = "NKE" #defines the ticker symbol of the company we want to analyze (NIKE)

# %%
stock_data = yf.Ticker(ticker_symbol) #gets the stock data for NIKE

# %%
hist_data_20 = stock_data.history(period="20d")# defines what period we want to get the data for; shorterm 20 days

# %%
display(hist_data_20.head()) #displays the stock data in a table with the headings
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-02-09 00:00:00-05:00  103.430471  104.566411  102.962143  104.127975
# 2024-02-12 00:00:00-05:00  104.367116  107.047541  104.277440  106.798431
# 2024-02-13 00:00:00-05:00  104.616224  105.423345  103.878860  104.626190
# 2024-02-14 00:00:00-05:00  104.446835  106.041138  104.088116  105.951462
# 2024-02-15 00:00:00-05:00  106.638995  106.957856  105.453237  105.672455
#
#                             Volume  Dividends  Stock Splits
# Date
# 2024-02-09 00:00:00-05:00  5449000        0.0           0.0
# 2024-02-12 00:00:00-05:00  7501900        0.0           0.0
# 2024-02-13 00:00:00-05:00  6180500        0.0           0.0
# 2024-02-14 00:00:00-05:00  5743300        0.0           0.0
# 2024-02-15 00:00:00-05:00  7201300        0.0           0.0

# %%
hist_data_20['Daily Return'] = hist_data_20['Close'].pct_change() #Adds a daily return column to the table
display(hist_data_20)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-02-09 00:00:00-05:00  103.430471  104.566411  102.962143  104.127975
# 2024-02-12 00:00:00-05:00  104.367116  107.047541  104.277440  106.798431
# 2024-02-13 00:00:00-05:00  104.616224  105.423345  103.878860  104.626190
# 2024-02-14 00:00:00-05:00  104.446835  106.041138  104.088116  105.951462
# 2024-02-15 00:00:00-05:00  106.638995  106.957856  105.453237  105.672455
# 2024-02-16 00:00:00-05:00  104.257510  104.327261  101.288123  103.141502
# 2024-02-20 00:00:00-05:00  102.762850  103.470322  101.806269  102.932251
# 2024-02-21 00:00:00-05:00  102.982063  105.144336  102.563560  104.895226
# 2024-02-22 00:00:00-05:00  105.423348  105.632599  103.709470  104.705910
# 2024-02-23 00:00:00-05:00  104.885266  106.240425  104.815516  105.253944
# 2024-02-26 00:00:00-05:00  104.935087  105.722275  103.390609  104.167831
# 2024-02-27 00:00:00-05:00  104.456797  104.875300  103.619784  104.775658
# ...

# %% [markdown]
# # **Data Cleaning**

# %%
hist_data_20.fillna('-', inplace=True)# Replace NaN values with a hyphen ('-') using .fillna()
display(hist_data_20)# Display the new table after replacing NaN values
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-02-09 00:00:00-05:00  103.430471  104.566411  102.962143  104.127975
# 2024-02-12 00:00:00-05:00  104.367116  107.047541  104.277440  106.798431
# 2024-02-13 00:00:00-05:00  104.616224  105.423345  103.878860  104.626190
# 2024-02-14 00:00:00-05:00  104.446835  106.041138  104.088116  105.951462
# 2024-02-15 00:00:00-05:00  106.638995  106.957856  105.453237  105.672455
# 2024-02-16 00:00:00-05:00  104.257510  104.327261  101.288123  103.141502
# 2024-02-20 00:00:00-05:00  102.762850  103.470322  101.806269  102.932251
# 2024-02-21 00:00:00-05:00  102.982063  105.144336  102.563560  104.895226
# 2024-02-22 00:00:00-05:00  105.423348  105.632599  103.709470  104.705910
# 2024-02-23 00:00:00-05:00  104.885266  106.240425  104.815516  105.253944
# 2024-02-26 00:00:00-05:00  104.935087  105.722275  103.390609  104.167831
# 2024-02-27 00:00:00-05:00  104.456797  104.875300  103.619784  104.775658
# ...

# %% [markdown]
# # **Data Visualization - 20 days**

# %%
import matplotlib.pyplot as plt #imports a sub library within matplotlib to help with visualizations

# %%
# %matplotlib inline

# %%
#Creates a plot for the stock data over 20 days

plt.figure(figsize=(20,6)) #determines the size of the graph
plt.plot(hist_data_20['Close'],color='pink',label='Nike stock over 20 days')# sets the information to be plotted, the legend label and the clolor of the line
plt.title('Nike\'s Closing Price Over 20 Days')# Adds the title to the graph
plt.xlabel('Closing Date')# Labels the x axis
plt.ylabel(' Closing price ')# Labels the y axis
plt.legend()# Adds a legend to the plot
plt.xticks(rotation=45)# Rotates the x axis so we can see the infromation more clearly
plt.tight_layout() # Adjust layout to prevent overlapping of any labels
plt.show() #Displays the plot

# %%
#Plots the volume traded in the last 20 days

volume_traded = hist_data_20['Volume']# gets what infromation needs to be plotted
plt.figure(figsize=(20,6))# determines the size of the plot
plt.plot(volume_traded, color='pink',label='Volume traded over 20 days')#plots the volume trades and sets the color labels the legend
plt.xlabel('Date')#Labels the x axis
plt.ylabel('Volume Traded')# Labels the y axis
plt.title('Nike\'s Volume Traded Over 20 Days')# Adds the title of the plot
plt.legend()# Adds a legend to the plot
plt.xticks(rotation=45)# Rotates the x axis so we can see the infromation more clearly
plt.tight_layout() # Adjust layout to prevent overlapping of any labels
plt.show() #Displays the plot

# %%
# Plots the 30 and 300 days moving average for the last 20 days

hist_data_20['30_Move_Avg'] = hist_data_20['Close'].rolling(window=30).mean() # Calculates the 30 day moving average for the closing prices over the last 20 days
hist_data_20['300_Move_Avg'] = hist_data_20['Close'].rolling(window=300).mean() # Calculates the 300 day moving average for the closing prices over the last 20 days
plt.figure(figsize=(20, 6)) #determines the size of the plot
plt.plot(hist_data_20['Close'], label='Close Price',color='pink')#Plots the  closing prices from the last 20 days,sets the label for the legend and sets the color of the line
plt.plot(hist_data_20['30_Move_Avg'], label='30 day Moving Average',color='violet')#Plots the  30 day moving average,sets the label for the legend and sets the color of the line
plt.plot(hist_data_20['300_Move_Avg'], label='300 Moving Average',color='yellow')#Plots the  300 day moving average,sets the label for the legend and sets the color of the line
plt.xlabel('Date') # Labels the x-axis
plt.ylabel('Price') # Labels the y-axis
plt.title('Moving Averages of Nike\'s Stock over the last 20 days ') # Adds the plot title
plt.xticks(rotation=45)# Rotates the x axis so we can see the infromation more clearly
plt.legend()# Adds a legend
plt.show()# Displays the  plot

# %% [markdown]
# # **Data Analysis - 20 days**

# %%
#Finds the max price over the last 20 days
max_price_20 = hist_data_20['Close'].max()
print(f"The max closing price after 20 days  is ${max_price_20:.2f}")
# Out:
# The max closing price after 20 days  is $106.80

# %%
#Finds the min price over the last 20 days
min_price_20 = hist_data_20['Close'].min()
print(f"The min closing price after 20 days is ${min_price_20:.2f}")
# Out:
# The min closing price after 20 days is $97.63

# %%
#Finds the percentage price over the last 20 days
percentage_change_20= (hist_data_20['Close'][-1]-hist_data_20['Close'][0]/hist_data_20['Close'][0]*100)
print(f"The percent change after 20 days is {percentage_change_20:.2f}%")
# Out:
# The percent change after 20 days  is -1.03%

# %%
#Finds the average price over the last 20 days
average_price_20 = hist_data_20['Close'].mean()
print(f"The average closing price after 20 days is ${average_price_20:.2f}")
# Out:
# The average closing price after 20 days is $102.96

# %%
#Finds the median price over the last 20days
median_price_20 = hist_data_20['Close'].median()
print(f"The median closing price after 20 days  is ${median_price_20:.2f}")
# Out:
# The median closing price after 20 days  is $104.05

# %% [markdown]
# # **Short Term Analysis Conclusion (Nike)**

# %% [markdown]
# 1. At the start of February 2024, Nike’s stock started off high.However, in mid February, the stock dropped went up a bit then started to drop again. After a bit research, we found that on February 16,2024 Nike announced that they were laying off 2% of its global workforce. We think this may be the reason for the drop in the stock.
#
# Source: https://www.opb.org/article/2024/02/16/nike-plans-layoff-2-percent-global-workforce/#:~:text=Feb.,in%20this%202020%20file%20photo.
#
# 2. Consequently, around this time of mid February, Nike saw and increase in their stock being traded.We believe this is because people started to sell their stock as the prices fell.
#
# 3. When comparing the 20 day moving average to 500 day moving average there is no data for the 30 and 300 day ing moving averages. We believe this is because there is not enough data for the time period to conduct the moving average.
#
# 4. However,our analysis tells us in the 20 day period, Nike stock still averages around $103.43

# %% [markdown]
# # **Data Fetching - Long Term Analysis (500 days )**

# %%
hist_data_500 = stock_data.history(period="500d")# defines what period we want to get the data for

# %%
display(hist_data_500.head()) #displays the stock data in a table with the headings
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2022-03-14 00:00:00-04:00  118.551112  119.448560  113.888279  114.688179
# 2022-03-15 00:00:00-04:00  116.902538  117.468323  114.863770  116.473328
# 2022-03-16 00:00:00-04:00  119.838745  123.018839  118.941297  122.121391
# 2022-03-17 00:00:00-04:00  121.877530  124.286987  120.667919  124.286987
# 2022-03-18 00:00:00-04:00  123.740701  128.237710  123.594376  128.023102
#
#                              Volume  Dividends  Stock Splits
# Date
# 2022-03-14 00:00:00-04:00  13884900        0.0           0.0
# 2022-03-15 00:00:00-04:00  10431300        0.0           0.0
# 2022-03-16 00:00:00-04:00  11100400        0.0           0.0
# 2022-03-17 00:00:00-04:00   6845300        0.0           0.0
# 2022-03-18 00:00:00-04:00  10350900        0.0           0.0

# %%
hist_data_500['Daily Return'] = hist_data_500['Close'].pct_change() #Adds a daily return column to the table
display(hist_data_500.head())
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2022-03-14 00:00:00-04:00  118.551112  119.448560  113.888279  114.688179
# 2022-03-15 00:00:00-04:00  116.902538  117.468323  114.863770  116.473328
# 2022-03-16 00:00:00-04:00  119.838745  123.018839  118.941297  122.121391
# 2022-03-17 00:00:00-04:00  121.877530  124.286987  120.667919  124.286987
# 2022-03-18 00:00:00-04:00  123.740701  128.237710  123.594376  128.023102
#
#                              Volume  Dividends  Stock Splits  Daily Return
# Date
# 2022-03-14 00:00:00-04:00  13884900        0.0           0.0           NaN
# 2022-03-15 00:00:00-04:00  10431300        0.0           0.0      0.015565
# 2022-03-16 00:00:00-04:00  11100400        0.0           0.0      0.048492
# 2022-03-17 00:00:00-04:00   6845300        0.0           0.0      0.017733
# 2022-03-18 00:00:00-04:00  10350900        0.0           0.0      0.030060

# %% [markdown]
# # **Data Cleaning**

# %%
hist_data_500.fillna('-', inplace=True)# Replace NaN values with a hyphen ('-') using .fillna()
display(hist_data_500)# Display the new table after replacing NaN values
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2022-03-14 00:00:00-04:00  118.551112  119.448560  113.888279  114.688179
# 2022-03-15 00:00:00-04:00  116.902538  117.468323  114.863770  116.473328
# 2022-03-16 00:00:00-04:00  119.838745  123.018839  118.941297  122.121391
# 2022-03-17 00:00:00-04:00  121.877530  124.286987  120.667919  124.286987
# 2022-03-18 00:00:00-04:00  123.740701  128.237710  123.594376  128.023102
# ...                               ...         ...         ...         ...
# 2024-03-04 00:00:00-05:00  101.650002  101.769997   99.010002   99.540001
# 2024-03-05 00:00:00-05:00   99.000000   99.169998   98.000000   98.309998
# 2024-03-06 00:00:00-05:00  100.000000  100.099998   97.059998   97.629997
# 2024-03-07 00:00:00-05:00   97.989998   98.400002   97.680000   98.190002
# 2024-03-08 00:00:00-05:00   98.489998   99.234001   98.019997   99.025002
#
#                              Volume  Dividends  Stock Splits Daily Return
# ...

# %% [markdown]
# # **Data Visualization - 500 days**

# %%
#Creates a plot for 500 days stock analysis
plt.figure(figsize=(20,6)) #determines the size of the graph
plt.plot(hist_data_500['Close'],color='pink',label='Nike stock over 500 days')# sets the information to be plotted, the legend label and the clolor of the line
plt.title('Nike\'s Closing Price Over 500 Days')# Adds the title to the graph
plt.xlabel('Closing Date')# Labels the x axis
plt.ylabel('Closing price ')# Labels the y axis
plt.legend()# Adds a legend to the plot
plt.xticks(rotation=45)# Rotates the x axis so we can see the infromation more clearly
plt.tight_layout() # Adjust layout to prevent overlapping of any labels
plt.show() #Displays the plot

# %%
#Plots the volume traded in the last 500 days
volume_traded = hist_data_500['Volume']# gets what infromation needs to be plotted
plt.figure(figsize=(20,6))# determines the size of the plot
plt.plot(volume_traded, color='pink',label='Volume traded over 500 days')#plots the volume trades and sets the color labels the legend
plt.xlabel('Date')#Labels the x axis
plt.ylabel('Volume Traded')# Labels the y axis
plt.title('Nike\'s Volume Traded Over 500 Days')# Adds the title of the plot
plt.legend()# Adds a legend to the plot
plt.xticks(rotation=45)# Rotates the x axis so we can see the infromation more clearly
plt.tight_layout() # Adjust layout to prevent overlapping of any labels
plt.show() #Displays the plot

# %%
# Plots the 30 and 300 days moving average for the last 500 days

hist_data_500['30_Move_Avg'] = hist_data_500['Close'].rolling(window=30).mean() # Calculates the 30 day moving average for the closing prices over the last 500 days
hist_data_500['300_Move_Avg'] = hist_data_500['Close'].rolling(window=300).mean() # Calculates the 300 day moving average for the closing prices over the last 500 days
plt.figure(figsize=(20, 6)) #determines the size of the plot
plt.plot(hist_data_500['Close'], label='Close Price',color='pink')#Plots the  closing prices from the last 500 days,sets the label for the legend and sets the color of the line
plt.plot(hist_data_500['30_Move_Avg'], label='30 day Moving Average',color='violet')#Plots the  50 day moving average,sets the label for the legend and sets the color of the line
plt.plot(hist_data_500['300_Move_Avg'], label='300 Moving Average',color='yellow')#Plots the  300 day moving average,sets the label for the legend and sets the color of the line
plt.xlabel('Date') # Labels the x-axis
plt.ylabel('Price') # Labels the y-axis
plt.title('Moving Averages of Nike\'s Stock over the last 500 days ') # Adds the plot title
plt.legend()# Adds a legend
plt.show()# Displays the  plot

# %% [markdown]
# # **Data Analysis - 500 days**

# %%
#Finds the max price over the last 500 days
max_price_500 = hist_data_500['Close'].max()
print(f"The max closing price after 500 days is ${max_price_500:.2f}")
# Out:
# The max closing price after 500 days is $135.73

# %%
#Finds the min price over the last 500 days
min_price_500 = hist_data_500['Close'].min()
print(f"The min closing price after 500 days is ${min_price_500:.2f}")
# Out:
# The min closing price after 500 days is $81.52

# %%
#Finds the average price over the last 500 days
average_price_500 = hist_data_500['Close'].mean()
print(f"The average closing price after 500 days is ${average_price_500:.2f}")
# Out:
# The average closing price after 500 days is $109.10

# %%
#Finds the median price over the last 500 days
median_price_500 = hist_data_500['Close'].median()
print(f"The median closing price after 500 days  is ${median_price_500:.2f}")
# Out:
# The median closing price after 500 days  is $107.26

# %%
#Finds the percentage change pover the last 500 days
percentage_change_500 = (hist_data_500['Close'][-1]-hist_data_500['Close'][0]/hist_data_500['Close'][0]*100)
print(f"The percent change after 500 days is {percentage_change_500:.2f}%")
# Out:
# The percent change after 500 days is -0.97%

# %% [markdown]
# # **Long Term Analysis Conclusion (Nike)**

# %% [markdown]
# 1. As we can see, there is clear contracted in the closing price of the stock and the volume traded. In October 2022, the volume traded was quite high but the cost of closing stock was at an all time low. This may because of negative news being circulated about the company or individuals just trying to sell some of their stocks
#
# 2. From the volume traded plot, we can obviously see that the amount of stock traded differs over the months of the years. It seems around July, October and January has the most volume traded. This may be because of Summer (July), Halloween(October) and the start of a new year(January).
#
# 3.  After researching how to read a moving average plot, we can say that since the closing price lince cross overs both moving average lines igt shows that there could possibly be changes over the years that affects the company's closing price especially in October 2022, when the moving average was very low.
#
# 4. After looking at Nike's percent change, it shows that their stock fell by 2.48% since it has been trading. As seen in the 20 day analysis, Nike's stock is still falling.
#
# **Note:**
# We had to research some terms to understand exactly we needed to do and how to understand the data.

# %% [markdown]
# # **HYATT STOCK ANLYSIS**

# %% [markdown]
# # **Data Fetching**

# %% [markdown]
# # **Short Term Analysis (20 Days)**

# %%
ticker_symbol = "H" #defines the ticker symbol of the company we want to analyze (Hyatt)

# %%
stock_data = yf.Ticker(ticker_symbol) #gets the stock data for Hyatt

# %%
hist_data_H20 = stock_data.history(period="20d")# defines what period we want to get the data for; shorterm 30 days

# %%
display(hist_data_H20.head()) #displays the stock data in a table with the headings
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-02-09 00:00:00-05:00  130.170665  130.580262  128.782045  130.350479
# 2024-02-12 00:00:00-05:00  130.899926  132.668173  130.650174  132.628204
# 2024-02-13 00:00:00-05:00  128.841979  128.841979  125.325469  126.384422
# 2024-02-14 00:00:00-05:00  126.933865  129.781042  125.665129  128.941879
# 2024-02-15 00:00:00-05:00  130.190641  134.806050  128.772038  134.196655
#
#                             Volume  Dividends  Stock Splits
# Date
# 2024-02-09 00:00:00-05:00   652900        0.0           0.0
# 2024-02-12 00:00:00-05:00   647200        0.0           0.0
# 2024-02-13 00:00:00-05:00   893000        0.0           0.0
# 2024-02-14 00:00:00-05:00  1138500        0.0           0.0
# 2024-02-15 00:00:00-05:00  1369200        0.0           0.0

# %%
hist_data_H20['Daily Return'] = hist_data_H20['Close'].pct_change() #Adds a daily return column to the table
display(hist_data_H20.head())
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-02-09 00:00:00-05:00  130.170665  130.580262  128.782045  130.350479
# 2024-02-12 00:00:00-05:00  130.899926  132.668173  130.650174  132.628204
# 2024-02-13 00:00:00-05:00  128.841979  128.841979  125.325469  126.384422
# 2024-02-14 00:00:00-05:00  126.933865  129.781042  125.665129  128.941879
# 2024-02-15 00:00:00-05:00  130.190641  134.806050  128.772038  134.196655
#
#                             Volume  Dividends  Stock Splits  Daily Return
# Date
# 2024-02-09 00:00:00-05:00   652900        0.0           0.0           NaN
# 2024-02-12 00:00:00-05:00   647200        0.0           0.0      0.017474
# 2024-02-13 00:00:00-05:00   893000        0.0           0.0     -0.047077
# 2024-02-14 00:00:00-05:00  1138500        0.0           0.0      0.020236
# 2024-02-15 00:00:00-05:00  1369200        0.0           0.0      0.040753

# %% [markdown]
# # **Data Cleaning**

# %%
hist_data_H20.fillna('-', inplace=True)# Replace NaN values with a hyphen ('-') using .fillna()
display(hist_data_H20)# Display the new table after replacing NaN values
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-02-09 00:00:00-05:00  130.170665  130.580262  128.782045  130.350479
# 2024-02-12 00:00:00-05:00  130.899926  132.668173  130.650174  132.628204
# 2024-02-13 00:00:00-05:00  128.841979  128.841979  125.325469  126.384422
# 2024-02-14 00:00:00-05:00  126.933865  129.781042  125.665129  128.941879
# 2024-02-15 00:00:00-05:00  130.190641  134.806050  128.772038  134.196655
# 2024-02-16 00:00:00-05:00  133.497360  133.847003  132.148694  132.698151
# 2024-02-20 00:00:00-05:00  132.768077  133.247611  131.918929  132.148697
# 2024-02-21 00:00:00-05:00  131.409420  133.697156  131.149684  133.417435
# 2024-02-22 00:00:00-05:00  134.546294  136.624231  134.426418  135.405441
# 2024-02-23 00:00:00-05:00  137.393483  150.510454  136.704165  150.020935
# 2024-02-26 00:00:00-05:00  150.670301  151.909061  149.311651  150.960007
# 2024-02-27 00:00:00-05:00  151.649994  151.899994  149.220001  151.470001
# ...

# %% [markdown]
# # **Data Visualization - 20 Days**

# %%
#Creates a plot for the Hyatt stock data over 30 days

plt.figure(figsize=(20,6)) #determines the size of the graph
plt.plot(hist_data_H20['Close'],color='green',label='Hyatt stock over 20 days')# sets the information to be plotted, the legend label and the clolor of the line
plt.title('Hyatt\'s Closing Price Over 20 Days')# Adds the title to the graph
plt.xlabel('Closing Date')# Labels the x axis
plt.ylabel(' Closing price')# Labels the y axis
plt.legend()# Adds a legend to the plot
plt.xticks(rotation=45)# Rotates the x axis so we can see the information more clearly
plt.tight_layout() # Adjust layout to prevent overlapping of any labels
plt.show() #Displays the plot

# %%
import seaborn as sns  # Imports the seaborn library to create plots

# %%
# Plots the volume traded in the last 20 days
volume_traded = hist_data_H20['Volume']  # gets the volume traded information
plt.figure(figsize=(20, 6))  # determines the size of the plot
sns.barplot(x=volume_traded.index, y=volume_traded, color='green')  # plots the volume trades as a bar plot using seaborn
plt.xlabel('Date')  # Labels the x axis
plt.ylabel('Volume Traded')  # Labels the y axis
plt.title('Hyatt\'s Volume Traded Over 20 Days')  # Adds the title of the plot
plt.xticks(rotation=45)  # Rotates the x axis so we can see the information more clearly
plt.tight_layout()  # Adjust layout to prevent overlapping of any labels
plt.show()  # Displays the plot

# %%
# Plots the 30 and 300 days moving average for the last 20 days

hist_data_H20['30_Move_Avg'] = hist_data_H20['Close'].rolling(window=30).mean()# Calculates the 30-day moving average for the closing prices over the last 30 days
hist_data_H20['300_Move_Avg'] = hist_data_H20['Close'].rolling(window=300).mean()# Calculates the 300-day moving average for the closing prices over the last 30 days

plt.figure(figsize=(20, 6)) # determines the size of the plot
plt.plot(hist_data_H20['Close'], label='Close Price', color='green') # Plots the closing prices from the last 30 days, sets the label for the legend, and sets the color of the line
plt.plot(hist_data_H20['30_Move_Avg'], label='30 day Moving Average', color='blue') # Plots the 30 day moving average, sets the label for the legend, and sets the color of the line
plt.plot(hist_data_H20['300_Move_Avg'], label='300 day Moving Average', color='brown') # Plots the 300 day moving average, sets the label for the legend, and sets the color of the line
plt.xlabel('Date') # Labels the x-axis
plt.ylabel('Price') # Labels the y-axis
plt.title('Moving Averages of Hyatt\' Stock over the last 20 days') # Adds the plot title
plt.legend() # Adds a legend
plt.show() # Displays the plot

# %% [markdown]
# # **Data Analysis 20 Days**

# %%
#Finds the max price over the last 20 days
max_price_H20 = hist_data_H20['Close'].max()
print(f"The max closing price after 20 days  is ${max_price_H20:.2f}")
# Out:
# The max closing price after 30 days  is $157.85

# %%
#Finds the min price over the last 20 days
min_price_H20 = hist_data_H20['Close'].min()
print(f"The min closing price after 20 days is ${min_price_H20:.2f}")
# Out:
# The min closing price after 20 days is $126.38

# %%
#Finds the percentage price over the last 20 days
percentage_change_H20= (hist_data_H20['Close'][-1]-hist_data_H20['Close'][0]/hist_data_H20['Close'][0]*100)
print(f"The percent change after 20 days  is {percentage_change_H20:.2f}%")
# Out:
# The percent change after 20 days  is 56.54%

# %%
#Finds the average price over the last 20 days
average_price_H20 = hist_data_H20['Close'].mean()
print(f"The average closing price after 20 days is ${average_price_H20:.2f}")
# Out:
# The average closing price after 30 days is $144.41

# %%
#Finds the median price over the last 20 days
median_price_H20 = hist_data_H20['Close'].median()
print(f"The median closing price after 20 days  is ${median_price_H20:.2f}")
# Out:
# The median closing price after 20 days  is $150.49

# %% [markdown]
# # **Short Term Analysis Conclusion (Hyatt)**

# %% [markdown]
# 1. Closing prices fell to the lowest out the 20 days on February 13,2023. this may be because investors got worried after they heard before hand that the company would be delaying the release of its 2034 fourth quarter earnings report. However, on Feb 14, the company released a statement and the closing price went up.
#
# source:https://newsroom.hyatt.com/news-releases?item=124460
#
# 2. The price of the stock stayed consistent until Feb 21 when it dramatically increased around Feb 22-23. We think it is because on Feb 23 they released their earning guidance for 2024.
#
# Source: https://in.marketscreener.com/quote/stock/HYATT-HOTELS-CORPORATION-5685450/news/Hyatt-Hotels-Corporation-Provides-Earnings-Guidance-for-the-Year-2024-46018325/
#
# 3.  The volume traded plot basically tell us the same, the amount of stock traded to greater on Feb 22 and Feb 23
#
# 4. Like Nike, the moving average models the closing price and there is not a lot of information to get an accurate moving averages plot

# %% [markdown]
# # **Data Fetching - Long Term Analysis (500 Days)**

# %%
hist_data_H500= stock_data.history(period="500d")# defines what period we want to get the data for

# %%
display(hist_data_H500.head()) #displays the stock data in a table with the headings
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2022-03-14 00:00:00-04:00  90.147782  90.824389  87.560761  88.884125
# 2022-03-15 00:00:00-04:00  90.247276  92.167643  88.794565  90.247276
# 2022-03-16 00:00:00-04:00  92.068157  93.729819  91.063196  93.580574
# 2022-03-17 00:00:00-04:00  91.859192  93.580560  91.102983  93.272102
# 2022-03-18 00:00:00-04:00  92.466153  94.804422  91.620397  93.779564
#
#                             Volume  Dividends  Stock Splits
# Date
# 2022-03-14 00:00:00-04:00   956700        0.0           0.0
# 2022-03-15 00:00:00-04:00   527700        0.0           0.0
# 2022-03-16 00:00:00-04:00  1012100        0.0           0.0
# 2022-03-17 00:00:00-04:00   862200        0.0           0.0
# 2022-03-18 00:00:00-04:00   707100        0.0           0.0

# %%
hist_data_H500['Daily Return'] = hist_data_H500['Close'].pct_change() #Adds a daily return column to the table
display(hist_data_H500)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2022-03-14 00:00:00-04:00   90.147782   90.824389   87.560761   88.884125
# 2022-03-15 00:00:00-04:00   90.247276   92.167643   88.794565   90.247276
# 2022-03-16 00:00:00-04:00   92.068157   93.729819   91.063196   93.580574
# 2022-03-17 00:00:00-04:00   91.859192   93.580560   91.102983   93.272102
# 2022-03-18 00:00:00-04:00   92.466153   94.804422   91.620397   93.779564
# ...                               ...         ...         ...         ...
# 2024-03-04 00:00:00-05:00  157.190002  158.320007  156.070007  157.520004
# 2024-03-05 00:00:00-05:00  156.899994  158.800003  156.820007  157.830002
# 2024-03-06 00:00:00-05:00  158.570007  159.809998  157.330002  157.339996
# 2024-03-07 00:00:00-05:00  157.529999  158.509995  155.759995  156.649994
# 2024-03-08 00:00:00-05:00  156.979996  158.639999  156.050003  156.669998
#
#                             Volume  Dividends  Stock Splits  Daily Return
# ...

# %% [markdown]
# # **Data Cleaning**

# %%
hist_data_H500.fillna('-', inplace=True)# Replace NaN values with a hyphen ('-') using .fillna()
display(hist_data_H500)# Display the new table after replacing NaN values
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2022-03-14 00:00:00-04:00   90.147782   90.824389   87.560761   88.884125
# 2022-03-15 00:00:00-04:00   90.247276   92.167643   88.794565   90.247276
# 2022-03-16 00:00:00-04:00   92.068157   93.729819   91.063196   93.580574
# 2022-03-17 00:00:00-04:00   91.859192   93.580560   91.102983   93.272102
# 2022-03-18 00:00:00-04:00   92.466153   94.804422   91.620397   93.779564
# ...                               ...         ...         ...         ...
# 2024-03-04 00:00:00-05:00  157.190002  158.320007  156.070007  157.520004
# 2024-03-05 00:00:00-05:00  156.899994  158.800003  156.820007  157.830002
# 2024-03-06 00:00:00-05:00  158.570007  159.809998  157.330002  157.339996
# 2024-03-07 00:00:00-05:00  157.529999  158.509995  155.759995  156.649994
# 2024-03-08 00:00:00-05:00  156.979996  158.639999  156.050003  156.669998
#
#                             Volume  Dividends  Stock Splits Daily Return
# ...

# %% [markdown]
# # **Data Visulaztion - 500 Days**

# %%
#Creates a plot for 500 days of stock analysis

plt.figure(figsize=(20,6)) #determines the size of the graph
plt.plot(hist_data_H500['Close'],color='Green',label='Hyatt\' stock over the last 500 days')# sets the information to be plotted, the legend label and the clolor of the line
plt.title('Hyatt\'s Closing Price Over 500 days')# Adds the title to the graph
plt.xlabel('Closing Date')# Labels the x axis
plt.ylabel('Closing price')# Labels the y axis
plt.legend()# Adds a legend to the plot
plt.xticks(rotation=45)# Rotates the x axis so we can see the infromation more clearly
plt.show() #Displays the plot

# %%
# Plots the volume traded in the last 500 days using Seaborn
volume_traded = hist_data_H500['Volume'] # Gets the information that is to be plotted
plt.figure(figsize=(20, 6))  # Determines the size of the plot
sns.lineplot(x=volume_traded.index, y=volume_traded, color='green',label='Volume Traded over 500 days') # plots the volume trades as a bar plot using seaborn
plt.xlabel('Date')  # Labels the x axis
plt.ylabel('Volume Traded')  # Labels the y axis
plt.title('Hyatt\'s Volume Traded Over 500 Days')  # Adds a title to the plot
plt.xticks(rotation=45)   # Rotates the x axis so we can see the label more clearly
plt.legend()# Adds a legend to the plot
plt.show()  # displays the plot

# %%
# Plots the 30 and 300 days moving average for the last 5 years

hist_data_H500['30_Move_Avg'] = hist_data_H500['Close'].rolling(window=30).mean() # Calculates the 30 day moving average for the closing prices over the last 6 years
hist_data_H500['300_Move_Avg'] = hist_data_H500['Close'].rolling(window=300).mean() # Calculates the 300 day moving average for the closing prices over the last 500 days
plt.figure(figsize=(20, 6)) #determines the size of the plot
plt.plot(hist_data_H500['Close'], label='Close Price',color='green')#Plots the  closing prices from the last years,sets the label for the legend and sets the color of the line
plt.plot(hist_data_H500['30_Move_Avg'], label='30 day Moving Average',color='blue')#Plots the  30 day moving average,sets the label for the legend and sets the color of the line
plt.plot(hist_data_H500['300_Move_Avg'], label='300 Moving Average',color='brown')#Plots the  300 day moving average,sets the label for the legend and sets the color of the line
plt.xlabel('Date') # Labels the x-axis
plt.ylabel('Price') # Labels the y-axis
plt.title('Moving Averages of Hyatt\'s Stock over the last 500 days ') # Adds the plot title
plt.legend()# Adds a legend
plt.show()# Displays the  plot

# %% [markdown]
# # **Data Analysis - 500 Days**

# %%
#Finds the max price over the last 500 days
max_price_H500 = hist_data_H500['Close'].max()
print(f"The max closing price after 500 Days is ${max_price_H500:.2f}")
# Out:
# The max closing price after 500 Days is $157.85

# %%
#Finds the min price over the last 500 days
min_price_H500 = hist_data_H500['Close'].min()
print(f"The min closing price after 500 Days is ${min_price_H500:.2f}")
# Out:
# The min closing price after 500 Days is $70.85

# %%
#Finds the median price over the last 500 days
median_price_H500 = hist_data_H500['Close'].median()
print(f"The median closing price after 500 days is ${median_price_H500:.2f}")
# Out:
# The median closing price after 500 days is $105.64

# %%
#Finds the percentage change over the last 500 days
percentage_change_H500 = (hist_data_H500['Close'][-1]-hist_data_H500['Close'][0]/hist_data_H500['Close'][0]*100)
print(f"The percent change after 500 days is {percentage_change_H500:.2f}%")
# Out:
# The percent change after 500 days is 56.54%

# %%
#Finds the average price over the last 500 days
average_price_H500 = hist_data_H500['Close'].mean()
print(f"The average closing price after 500 days is ${average_price_H500:.2f}")
# Out:
# The average closing price after 500 days is $104.46

# %% [markdown]
# # **Long Term Analysis Conclusion**

# %% [markdown]
# 1. Over the 500 days, we can a fluctuating market.
#
# 2. The moving average shows that between April 2022 the market was down and it started improving between Jan,2023-April 2023
#
# 3. The max stock for the short term and long term was the same at $157.85

# %% [markdown]
# # **Analysis of both companies in the same time period**
#
# **20 Days**
#
#
#
# 1.   We understand that both companies are in different industries so therefore comparing them during the same time period may be diffcult.
#
# 2.   Based on data analysis, overall Hyatt and a better 20 days than Nike.
#
# 3. Hyatt stock had a positive percent change, while Nike had a negative percent change.
#
# **500 Days**
#
# 1. Even going back 500 days, Hyatt seemed to have stock performance.
#
# 2. Again Nike had a negative percent change while hyatt had a positive.

# %% [markdown]
# # **Project Conclusion**

# %% [markdown]
# In this project, we embarked on a journey to enhance our Python proficiency through practical application in analyzing stock data from NIKE and Hyatt, sourced from Yahoo Finance APIs. Leveraging pandas, matplotlib, seaborn, and matplotlib.pyplot libraries, we delved into the intricacies of data manipulation and analysis, refining our skills in extracting actionable insights from financial datasets. Through meticulous examination of the stock data spanning 20 and 500 days, we engaged in various analytical operations, including calculating moving averages and visualizing stock price trends. This hands-on experience not only deepened our understanding of fundamental data science operations but also provided valuable insights into the dynamic nature of the stock market.
